# %%
import importlib
import os
from pathlib import Path
import sys
from urllib.parse import urlparse

from arcgis.features import GeoAccessor, FeatureLayer
from arcgis.gis import GIS
from arcgis.mapping import WebMap
from dotenv import load_dotenv, find_dotenv
import pandas as pd
import numpy as np

# %%
# paths to common data locations - NOTE: to convert any path to a raw string, simply use str(path_instance)
dir_prj = Path.cwd().parent
dir_data = dir_prj/'data'
dir_int = dir_data/'interim'
gdb_int = dir_int/'interim.gdb'

# import the project package from the project package path - only necessary if you are not using a unique environemnt for this project
sys.path.append(str(dir_prj/'src'))
import rec_data

# load the "autoreload" extension so that code can change, & always reload modules so that as you change code in src, it gets loaded
# %load_ext autoreload
# %autoreload 2

# load environment variables from .env
load_dotenv(find_dotenv())

# create a GIS object instance; if you did not enter any information here, it defaults to anonymous access to ArcGIS Online
gis = GIS(
    url=os.getenv('ESRI_GIS_URL'), 
    username=os.getenv('ESRI_GIS_USERNAME'),
    password=None if len(os.getenv('ESRI_GIS_PASSWORD')) is 0 else os.getenv('ESRI_GIS_PASSWORD')
)

gis
# Out:
# GIS @ https://knu2xs.maps.arcgis.com version:9.1

# %%
map_itm_id = '313923e7f415433594587911a3df3a39'

admin_dict = {
    'gis.blm.gov': 'BLM',
    'mapservices.nps.gov': 'NPS',
    'apps.fs.usda.gov': 'USFS',
    'gismanager.rco.wa.gov': 'WA'
}

# %%
itm = gis.content.get(map_itm_id)

wm = WebMap(itm)

lyr_set = set((lyr.title, lyr.url) for lyr in wm.layers)

lyr_df = pd.DataFrame(lyr_set, columns=['name', 'url']).sort_values('name').reset_index(drop=True)

lyr_df.head()
# Out:
#                                                 name  \
# 0                                 BLM Land Ownership
# 1  BLM Roads Managed for Limited Public Motorized...
# 2         BLM Roads Managed for Public Motorized Use
# 3  BLM Trails Managed for Limited Public Motorize...
# 4                      BLM Trails Managed for Public
#
#                                                  url
# 0  https://gis.blm.gov/arcgis/rest/services/lands...
# 1  https://gis.blm.gov/arcgis/rest/services/trans...
# 2  https://gis.blm.gov/arcgis/rest/services/trans...
# 3  https://gis.blm.gov/arcgis/rest/services/trans...
# 4  https://gis.blm.gov/arcgis/rest/services/trans...

# %%
lyr_df['admin_agency'] = lyr_df.url.apply(lambda url: admin_dict[urlparse(url).netloc])

lyr_df
# Out:
#                                                  name  \
# 0                                  BLM Land Ownership
# 1   BLM Roads Managed for Limited Public Motorized...
# 2          BLM Roads Managed for Public Motorized Use
# 3   BLM Trails Managed for Limited Public Motorize...
# 4                       BLM Trails Managed for Public
# 5         BLM Trails Managed for Public Motorized Use
# 6    BLM Trails Managed for Public Non-Mechanized Use
# 7     BLM Trails Managed for Public Non-Motorized Use
# 8                  BLM Trails Not Assessed for Public
# 9              US NPS Public Roads - NPS Public Roads
# 10                                      US NPS Trails
# 11                                  US NPS Wilderness
# 12                      USFS National Forest Boundary
# 13                                         USFS Roads
# 14                USFS Roads Closed to Motorized Uses
# 15                                        USFS Trails
# 16                                    USFS Wilderness
# 17                                          WA Trails
#
#                                                   url admin_agency
# 0   https://gis.blm.gov/arcgis/rest/services/lands...          BLM
# 1   https://gis.blm.gov/arcgis/rest/services/trans...          BLM
# 2   https://gis.blm.gov/arcgis/rest/services/trans...          BLM
# 3   https://gis.blm.gov/arcgis/rest/services/trans...          BLM
# 4   https://gis.blm.gov/arcgis/rest/services/trans...          BLM
# 5   https://gis.blm.gov/arcgis/rest/services/trans...          BLM
# 6   https://gis.blm.gov/arcgis/rest/services/trans...          BLM
# 7   https://gis.blm.gov/arcgis/rest/services/trans...          BLM
# 8   https://gis.blm.gov/arcgis/rest/services/trans...          BLM
# 9   https://mapservices.nps.gov/arcgis/rest/servic...          NPS
# 10  https://mapservices.nps.gov/arcgis/rest/servic...          NPS
# 11  https://mapservices.nps.gov/arcgis/rest/servic...          NPS
# 12  https://apps.fs.usda.gov/fsgisx05/rest/service...         USFS
# 13  https://apps.fs.usda.gov/fsgisx05/rest/service...         USFS
# 14  https://apps.fs.usda.gov/fsgisx05/rest/service...         USFS
# 15  https://apps.fs.usda.gov/fsgisx05/rest/service...         USFS
# 16  https://apps.fs.usda.gov/fsgisx05/rest/service...         USFS
# 17  https://gismanager.rco.wa.gov/arcgis/rest/serv...           WA

# %%
def get_category(val):
    val = val.lower()
    if ('road' in val) or ('motorized' in val):
        cat = 'road'
    elif 'trail' in val:
        cat = 'trail'
    elif ('boundary' in val) or ('wilderness' in val) or ('land' in val):
        cat = 'area'
    else:
        cat = np.Nan
    return cat

lyr_df['layer_type'] = lyr_df.name.apply(lambda val: get_category(val))

lyr_df
# Out:
#                                                  name  \
# 0                                  BLM Land Ownership
# 1   BLM Roads Managed for Limited Public Motorized...
# 2          BLM Roads Managed for Public Motorized Use
# 3   BLM Trails Managed for Limited Public Motorize...
# 4                       BLM Trails Managed for Public
# 5         BLM Trails Managed for Public Motorized Use
# 6    BLM Trails Managed for Public Non-Mechanized Use
# 7     BLM Trails Managed for Public Non-Motorized Use
# 8                  BLM Trails Not Assessed for Public
# 9              US NPS Public Roads - NPS Public Roads
# 10                                      US NPS Trails
# 11                                  US NPS Wilderness
# 12                      USFS National Forest Boundary
# 13                                         USFS Roads
# 14                USFS Roads Closed to Motorized Uses
# 15                                        USFS Trails
# 16                                    USFS Wilderness
# 17                                          WA Trails
#
#                                                   url admin_agency layer_type
# 0   https://gis.blm.gov/arcgis/rest/services/lands...          BLM       area
# 1   https://gis.blm.gov/arcgis/rest/services/trans...          BLM       road
# 2   https://gis.blm.gov/arcgis/rest/services/trans...          BLM       road
# 3   https://gis.blm.gov/arcgis/rest/services/trans...          BLM       road
# 4   https://gis.blm.gov/arcgis/rest/services/trans...          BLM      trail
# 5   https://gis.blm.gov/arcgis/rest/services/trans...          BLM       road
# 6   https://gis.blm.gov/arcgis/rest/services/trans...          BLM      trail
# 7   https://gis.blm.gov/arcgis/rest/services/trans...          BLM       road
# 8   https://gis.blm.gov/arcgis/rest/services/trans...          BLM      trail
# 9   https://mapservices.nps.gov/arcgis/rest/servic...          NPS       road
# 10  https://mapservices.nps.gov/arcgis/rest/servic...          NPS      trail
# 11  https://mapservices.nps.gov/arcgis/rest/servic...          NPS       area
# 12  https://apps.fs.usda.gov/fsgisx05/rest/service...         USFS       area
# 13  https://apps.fs.usda.gov/fsgisx05/rest/service...         USFS       road
# 14  https://apps.fs.usda.gov/fsgisx05/rest/service...         USFS       road
# 15  https://apps.fs.usda.gov/fsgisx05/rest/service...         USFS      trail
# 16  https://apps.fs.usda.gov/fsgisx05/rest/service...         USFS       area
# 17  https://gismanager.rco.wa.gov/arcgis/rest/serv...           WA      trail

# %%
usfs_trl_url = lyr_df[(lyr_df.admin_agency == 'USFS') & (lyr_df.layer_type == 'trail')].iloc[0].url
usfs_trl_df = FeatureLayer(usfs_trl_url).query().sdf

print(usfs_trl_df.info())
usfs_trl_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2413 entries, 0 to 2412
# Data columns (total 65 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   TRAIL_NO                        2413 non-null   object
#  1   TRAIL_NAME                      1961 non-null   object
#  2   TRAIL_TYPE                      2413 non-null   object
#  3   TRAIL_CN                        2413 non-null   object
#  4   BMP                             2413 non-null   float64
#  5   EMP                             2413 non-null   float64
#  6   SEGMENT_LENGTH                  2413 non-null   float64
#  7   ADMIN_ORG                       2413 non-null   object
#  8   MANAGING_ORG                    2413 non-null   object
#  9   SECURITY_ID                     2413 non-null   object
#  10  ATTRIBUTESUBSET                 2413 non-null   object
#  11  NATIONAL_TRAIL_DESIGNATION      2413 non-null   int64
#  12  TRAIL_CLASS                     2413 non-null   object
#  13  ACCESSIBILITY_STATUS            2413 non-null   object
#  14  TRAIL_SURFACE                   2413 non-null   object
#  15  SURFACE_FIRMNESS                2413 non-null   object
#  16  TYPICAL_TRAIL_GRADE             2413 non-null   object
#  17  TYPICAL_TREAD_WIDTH             2413 non-null   object
#  18  MINIMUM_TRAIL_WIDTH             2413 non-null   object
#  19  TYPICAL_TREAD_CROSS_SLOPE       2413 non-null   object
#  20  SPECIAL_MGMT_AREA               2413 non-null   object
#  21  TERRA_BASE_SYMBOLOGY            2410 non-null   object
#  22  MVUM_SYMBOL                     2413 non-null   int64
#  23  ALLOWED_TERRA_USE               2413 non-null   object
#  24  ALLOWED_SNOW_USE                2413 non-null   object
#  25  HIKER_PEDESTRIAN_MANAGED        2413 non-null   object
#  26  HIKER_PEDESTRIAN_ACCPT_DISC     2413 non-null   object
#  27  HIKER_PEDESTRIAN_RESTRICTED     2413 non-null   object
#  28  PACK_SADDLE_MANAGED             2413 non-null   object
#  29  PACK_SADDLE_ACCPT_DISC          2413 non-null   object
#  30  PACK_SADDLE_RESTRICTED          2413 non-null   object
#  31  BICYCLE_MANAGED                 2413 non-null   object
#  32  BICYCLE_ACCPT_DISC              2413 non-null   object
#  33  BICYCLE_RESTRICTED              2413 non-null   object
#  34  MOTORCYCLE_MANAGED              2413 non-null   object
#  35  MOTORCYCLE_ACCPT_DISC           2413 non-null   object
#  36  MOTORCYCLE_RESTRICTED           2413 non-null   object
#  37  ATV_MANAGED                     2413 non-null   object
#  38  ATV_ACCPT_DISC                  2413 non-null   object
#  39  ATV_RESTRICTED                  2413 non-null   object
#  40  FOURWD_MANAGED                  2413 non-null   object
#  41  FOURWD_ACCPT_DISC               2413 non-null   object
#  42  FOURWD_RESTRICTED               2413 non-null   object
#  43  SNOWMOBILE_MANAGED              2413 non-null   object
#  44  SNOWMOBILE_ACCPT_DISC           2413 non-null   object
#  45  SNOWMOBILE_RESTRICTED           2413 non-null   object
#  46  SNOWSHOE_MANAGED                2413 non-null   object
#  47  SNOWSHOE_ACCPT_DISC             2413 non-null   object
#  48  SNOWSHOE_RESTRICTED             2413 non-null   object
#  49  XCOUNTRY_SKI_MANAGED            2413 non-null   object
#  50  XCOUNTRY_SKI_ACCPT_DISC         2413 non-null   object
#  51  XCOUNTRY_SKI_RESTRICTED         2413 non-null   object
#  52  MOTOR_WATERCRAFT_MANAGED        2413 non-null   object
#  53  MOTOR_WATERCRAFT_ACCPT_DISC     2413 non-null   object
#  54  MOTOR_WATERCRAFT_RESTRICTED     2413 non-null   object
#  55  NONMOTOR_WATERCRAFT_MANAGED     2413 non-null   object
#  56  NONMOTOR_WATERCRAFT_ACCPT_DISC  2413 non-null   object
#  57  NONMOTOR_WATERCRAFT_RESTRICTED  2413 non-null   object
#  58  GIS_MILES                       2413 non-null   float64
#  59  TERRA_MOTORIZED                 2413 non-null   object
#  60  SNOW_MOTORIZED                  2413 non-null   object
#  61  WATER_MOTORIZED                 2413 non-null   object
#  62  OBJECTID                        2413 non-null   int64
#  63  SHAPE_Length                    2413 non-null   float64
#  64  SHAPE                           2413 non-null   geometry
# dtypes: float64(5), geometry(1), int64(3), object(56)
# memory usage: 1.2+ MB
# None
#   TRAIL_NO TRAIL_NAME TRAIL_TYPE      TRAIL_CN  BMP    EMP  SEGMENT_LENGTH  \
# 0  18EV412       None      TERRA  323250010602  0.0  1.769           1.769
# 1  17EV401       None      TERRA  323251010602  0.0  1.141           1.141
# 2  18EV409       None      TERRA  323248010602  0.0  1.026           1.026
# 3  18DC485       None      TERRA  322421010602  0.0  0.058           0.058
# 4  18EV408       None      TERRA  323247010602  0.0  0.163           0.163
#
#   ADMIN_ORG MANAGING_ORG SECURITY_ID  ... NONMOTOR_WATERCRAFT_MANAGED  \
# 0    051654       051654        0516  ...                         N/A
# 1    051654       051654        0516  ...                         N/A
# 2    051654       051654        0516  ...                         N/A
# 3    051651       051651        0516  ...                         N/A
# 4    051654       051654        0516  ...                         N/A
#
#    NONMOTOR_WATERCRAFT_ACCPT_DISC NONMOTOR_WATERCRAFT_RESTRICTED GIS_MILES  \
# 0                             N/A                            N/A     1.722
# 1                             N/A                            N/A     1.180
# 2                             N/A                            N/A     0.897
# 3                             N/A                            N/A     0.017
# 4                             N/A                            N/A     0.163
#
#   TERRA_MOTORIZED SNOW_MOTORIZED WATER_MOTORIZED OBJECTID SHAPE_Length  \
# 0             N/A            N/A             N/A       22  3605.892883
# 1             N/A            N/A             N/A       23  2330.534785
# 2             N/A            N/A             N/A       24  1840.112250
# 3             N/A            N/A             N/A       25    37.162609
# 4             N/A            N/A             N/A       26   333.114299
#
#                                                SHAPE
# 0  {"paths": [[[-13353048.1357, 4564446.605400003...
# 1  {"paths": [[[-13365078.46, 4564799.013599999],...
# 2  {"paths": [[[-13358913.8565, 4564884.203500003...
# 3  {"paths": [[[-13362515.2314, 4605467.162699997...
# 4  {"paths": [[[-13359826.808400001, 4564428.2088...
#
# [5 rows x 65 columns]

# %%
usfs_trl_df.TRAIL_TYPE.unique()
# Out:
# array(['TERRA'], dtype=object)

# %%
r = usfs_trl_df[usfs_trl_df.TRAIL_NAME.notnull()].iloc[0]

# %%
usfs_trl_df.columns.to_frame()
# Out:
#                                0
# TRAIL_NO                TRAIL_NO
# TRAIL_NAME            TRAIL_NAME
# TRAIL_TYPE            TRAIL_TYPE
# TRAIL_CN                TRAIL_CN
# BMP                          BMP
# ...                          ...
# SNOW_MOTORIZED    SNOW_MOTORIZED
# WATER_MOTORIZED  WATER_MOTORIZED
# OBJECTID                OBJECTID
# SHAPE_Length        SHAPE_Length
# SHAPE                      SHAPE
#
# [65 rows x 1 columns]

# %%
null_df = usfs_trl_df.notna().all().to_frame()
null_df[null_df[0].notnull()]
# Out:
#                      0
# TRAIL_NO          True
# TRAIL_NAME       False
# TRAIL_TYPE        True
# TRAIL_CN          True
# BMP               True
# ...                ...
# SNOW_MOTORIZED    True
# WATER_MOTORIZED   True
# OBJECTID          True
# SHAPE_Length      True
# SHAPE             True
#
# [65 rows x 1 columns]
